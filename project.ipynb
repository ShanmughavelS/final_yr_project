# %% [markdown]
# <a href="https://colab.research.google.com/github/ShanmughavelS/final_yr_project/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Credit Default Prediction: Assessing Risk of Payment Default Among Credit Card Clients**

# %% [markdown]
# # **Install & Import Libraries**

# %%
#installing UCIMLrepo lib to get direct access to datasets
# !pip install ucimlrepo

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from ucimlrepo import fetch_ucirepo

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # **Load Dataset**

# %%
# Fetch dataset from UCI repository
credit_default = fetch_ucirepo(id=350)

# Features and target
X = credit_default.data.features
y = credit_default.data.targets

# Combine into a single DataFrame
df = pd.concat([X, y], axis=1)

# Shape of dataset
df.shape
# Out:
# (30000, 24)

# %% [markdown]
# # **Rename Columns**

# %%
df.rename(columns={
    'X1': 'LIMIT_BAL',
    'X2': 'SEX',
    'X3': 'EDUCATION',
    'X4': 'MARRIAGE',
    'X5': 'AGE',
    'X6': 'PAY_0',
    'X7': 'PAY_2',
    'X8': 'PAY_3',
    'X9': 'PAY_4',
    'X10': 'PAY_5',
    'X11': 'PAY_6',
    'X12': 'BILL_AMT1',
    'X13': 'BILL_AMT2',
    'X14': 'BILL_AMT3',
    'X15': 'BILL_AMT4',
    'X16': 'BILL_AMT5',
    'X17': 'BILL_AMT6',
    'X18': 'PAY_AMT1',
    'X19': 'PAY_AMT2',
    'X20': 'PAY_AMT3',
    'X21': 'PAY_AMT4',
    'X22': 'PAY_AMT5',
    'X23': 'PAY_AMT6',
    'Y': 'default'
}, inplace=True)

# Verify column names
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default'],
#       dtype='object')

# %% [markdown]
# # **Basic Inspection**

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LIMIT_BAL  30000 non-null  int64
#  1   SEX        30000 non-null  int64
#  2   EDUCATION  30000 non-null  int64
#  3   MARRIAGE   30000 non-null  int64
#  4   AGE        30000 non-null  int64
#  5   PAY_0      30000 non-null  int64
#  6   PAY_2      30000 non-null  int64
#  7   PAY_3      30000 non-null  int64
#  8   PAY_4      30000 non-null  int64
#  9   PAY_5      30000 non-null  int64
#  10  PAY_6      30000 non-null  int64
#  11  BILL_AMT1  30000 non-null  int64
#  12  BILL_AMT2  30000 non-null  int64
#  13  BILL_AMT3  30000 non-null  int64
#  14  BILL_AMT4  30000 non-null  int64
#  15  BILL_AMT5  30000 non-null  int64
#  16  BILL_AMT6  30000 non-null  int64
#  17  PAY_AMT1   30000 non-null  int64
#  18  PAY_AMT2   30000 non-null  int64
#  19  PAY_AMT3   30000 non-null  int64
# ...

# %%
df.describe().T
# Out:
#              count           mean            std       min       25%  \
# LIMIT_BAL  30000.0  167484.322667  129747.661567   10000.0  50000.00
# SEX        30000.0       1.603733       0.489129       1.0      1.00
# EDUCATION  30000.0       1.853133       0.790349       0.0      1.00
# MARRIAGE   30000.0       1.551867       0.521970       0.0      1.00
# AGE        30000.0      35.485500       9.217904      21.0     28.00
# PAY_0      30000.0      -0.016700       1.123802      -2.0     -1.00
# PAY_2      30000.0      -0.133767       1.197186      -2.0     -1.00
# PAY_3      30000.0      -0.166200       1.196868      -2.0     -1.00
# PAY_4      30000.0      -0.220667       1.169139      -2.0     -1.00
# PAY_5      30000.0      -0.266200       1.133187      -2.0     -1.00
# PAY_6      30000.0      -0.291100       1.149988      -2.0     -1.00
# BILL_AMT1  30000.0   51223.330900   73635.860576 -165580.0   3558.75
# BILL_AMT2  30000.0   49179.075167   71173.768783  -69777.0   2984.75
# ...

# %% [markdown]
# ## **Check Missing Values**

# %%
df.isnull().sum()
# Out:
# LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_0        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# default      0
# dtype: int64

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# ## **Target Variable Imbalance**

# %%
df['default'].value_counts(normalize=True)
# Out:
# default
# 0    0.7788
# 1    0.2212
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='default', data=df)
plt.title("Class Distribution (Default vs Non-Default)")
plt.xlabel("Default (1 = Yes, 0 = No)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## **Correlation Matrix**

# %%
# Calculate correlation with the target and sort
top_corr_features = df.corr()['default'].abs().sort_values(ascending=False).head(11).index

# Plotting the heatmap for only these features
plt.figure(figsize=(10, 8))
sns.heatmap(
    df[top_corr_features].corr(),
    annot=True,
    fmt=".2f",
    cmap='RdBu_r',
    center=0,
    linewidths=0.5
)
plt.title("Top 10 Features Correlated with Default")
plt.show()
